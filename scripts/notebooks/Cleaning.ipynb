# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import requests
import pandas as pd
import os
import time
import json
import pyarrow.parquet as pq
import xml.etree.ElementTree as ET
# Set your Azure Maps API key
os.environ['AZURE_MAPS_API_KEY'] = 'AD576KfHVdRyigkX4bIyXg0s0nX1amIbJ8qzqwj7P5WhT02ajscjJQQJ99AJACYeBjFXZEq6AAAgAZMP4GmV'  # Replace with your Azure Maps API key
api_key = os.environ.get('AZURE_MAPS_API_KEY')

# Function to fetch country and region from Azure Maps API
def get_location_info(reviewer_location):
    try:
        url = f'https://atlas.microsoft.com/search/address/json?api-version=1.0&query={reviewer_location}&subscription-key={api_key}'
        response = requests.get(url)
        data = response.json()

        # Check if results exist and extract country and region
        if 'results' in data and len(data['results']) > 0:
            country = None
            region = None

            address = data['results'][0].get('address', {})

            country = address.get('country')
            region = address.get('countrySubdivision')  # Corrected to get 'countrySubdivision'

            return country, region
        else:
            print(f"No results found for {reviewer_location}")
            return None, None
    except Exception as e:
        print(f"Error fetching location info for {reviewer_location}: {e}")
        return None, None

# Function to create folder if it doesn't exist
def create_folder_if_not_exist(folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

# Function to process CSV files
def process_csv(input_path, output_path):
    df = pd.read_csv(input_path)
    df['country'] = None
    df['region'] = None

    for index, row in df.iterrows():
        reviewer_location = row['reviewer_location']
        if pd.notna(reviewer_location):
            country, region = get_location_info(reviewer_location)
            df.at[index, 'country'] = country
            df.at[index, 'region'] = region
            time.sleep(0.1)  # Throttle requests to avoid rate limits

    df.to_csv(output_path, index=False)
    print(f"Processed {input_path} and saved to {output_path}")

# Function to process JSON files
def process_json(input_path, output_path):
    with open(input_path, 'r') as file:
        data = json.load(file)

    for review in data:
        reviewer_location = review.get('reviewer_location')
        if reviewer_location:
            country, region = get_location_info(reviewer_location)
            review['country'] = country
            review['region'] = region
            time.sleep(0.1)

    with open(output_path, 'w') as file:
        json.dump(data, file, indent=4)
    print(f"Processed {input_path} and saved to {output_path}")

# Function to process Parquet files
def process_parquet(input_path, output_path):
    df = pq.read_table(input_path).to_pandas()
    df['country'] = None
    df['region'] = None

    for index, row in df.iterrows():
        reviewer_location = row['reviewer_location']
        if pd.notna(reviewer_location):
            country, region = get_location_info(reviewer_location)
            df.at[index, 'country'] = country
            df.at[index, 'region'] = region
            time.sleep(0.1)  # Throttle requests to avoid rate limits

    df.to_parquet(output_path, index=False)
    print(f"Processed {input_path} and saved to {output_path}")

# Function to process XML files
def process_xml(input_path, output_path):
    tree = ET.parse(input_path)
    root = tree.getroot()

    for review in root.findall('review'):
        reviewer_location = review.find('reviewer_location').text
        if reviewer_location:
            country, region = get_location_info(reviewer_location)
            country_elem = ET.SubElement(review, 'country')
            region_elem = ET.SubElement(review, 'region')
            country_elem.text = country
            region_elem.text = region
            time.sleep(0.1)  # Throttle requests to avoid rate limits

    tree.write(output_path)
    print(f"Processed {input_path} and saved to {output_path}")

# Function to get the sorted file list by size
def get_sorted_files_by_size(folder_path, file_extension):
    files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith(file_extension)]
    files.sort(key=lambda x: os.path.getsize(x))  # Sort files by size (smallest first)
    return files

# Main function to process files, starting with the smallest
def process_all_files(input_base_path, output_base_path):
    # Create output folders if they don't exist
    create_folder_if_not_exist(output_base_path)

    # Process CSV files
    csv_input_folder = os.path.join(input_base_path, 'csv')
    csv_output_folder = os.path.join(output_base_path, 'csv')
    create_folder_if_not_exist(csv_output_folder)

    csv_files = get_sorted_files_by_size(csv_input_folder, '.csv')
    for input_file in csv_files:
        file_name = os.path.basename(input_file)
        output_file = os.path.join(csv_output_folder, file_name)
        process_csv(input_file, output_file)

    # Process JSON files
    json_input_folder = os.path.join(input_base_path, 'json')
    json_output_folder = os.path.join(output_base_path, 'json')
    create_folder_if_not_exist(json_output_folder)

    json_files = get_sorted_files_by_size(json_input_folder, '.json')
    for input_file in json_files:
        file_name = os.path.basename(input_file)
        output_file = os.path.join(json_output_folder, file_name)
        process_json(input_file, output_file)

    # Process Parquet files
    parquet_input_folder = os.path.join(input_base_path, 'parquet')
    parquet_output_folder = os.path.join(output_base_path, 'parquet')
    create_folder_if_not_exist(parquet_output_folder)

    parquet_files = get_sorted_files_by_size(parquet_input_folder, '.parquet')
    for input_file in parquet_files:
        file_name = os.path.basename(input_file)
        output_file = os.path.join(parquet_output_folder, file_name)
        process_parquet(input_file, output_file)

    # Process XML files
    xml_input_folder = os.path.join(input_base_path, 'xml')
    xml_output_folder = os.path.join(output_base_path, 'xml')
    create_folder_if_not_exist(xml_output_folder)

    xml_files = get_sorted_files_by_size(xml_input_folder, '.xml')
    for input_file in xml_files:
        file_name = os.path.basename(input_file)
        output_file = os.path.join(xml_output_folder, file_name)
        process_xml(input_file, output_file)

# Example usage
input_base_path = '/content/drive/MyDrive/Sentiment_Sifters/data/cleaned_loc'
output_base_path = '/content/drive/MyDrive/Sentiment_Sifters/data/country_loc'
process_all_files(input_base_path, output_base_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# No results found for Chico, CA USA
# No results found for Every thing is bigger n better in Texas
# No results found for Atlantic Beach, NC
# No results found for Brazil
# No results found for Los Angeles, CA
# No results found for Nowhere worth mentioning
# No results found for Clinton, MS USA
# No results found for Inwood, New York
# No results found for Chicago Suburbs, IL United States
# No results found for Texas
# No results found for Butler, PA
# No results found for Boston, MA USA
# No results found for Oceanside, CA, USA
# No results found for Spokane, WA
# No results found for USA
# No results found for New Mexico
# No results found for Montana
# No results found for Reno, NV
# No results found for Los Angeles, CA USA
# No results found for Blossburg Pa.
# No results found for Seattle, WA
# No results found for Illinois USA
# No results found for Michigan
# No results found for San Diego
# No results found for USA
# No results found for Iowa USA
# No results found for Waxahachie, TX
# No results found for Long Beach, CA USA
# No results found for Philadelphia, PA USA
# No results found for Black Mountain, NC USA
# No results found for Arcadia, Kansas United States
# No results found for California, USA
# No results found for West Texas
# No results found for MI, USA
# No results found for NY
# No results found for Louisville, Kentucky United States
# No results found for Queens, New York
# No results found for Dallas
# No results found for Portland, Oregon
# No results found for Dayton, Ohio
# No results found for San Francisco, CA
# No results found for Forestville, CA USA
# No results found for Bay Area, CA USA
# No results found for Saint Louis Park, MN
# No results found for NYC
# No results found for Philadelphia, PA USA
# No results found for Portland, OR
# No results found for Scotts Valley, CA United States
# No results found for Nashville, TN
# No results found for Pleasantville, NY USA
# No results found for Alexandria, VA
# No results found for Kentucky
# No results found for Houston
# No results found for Norman, Oklahoma
# No results found for Mtns
# No results found for Westville, NJ United States
# No results found for Seattle
# No results found for Georgia
# No results found for Houston, TX
# No results found for New York, NY USA
# No results found for Sunnyvale, Ca United States
# No results found for Tallahassee
# No results found for Albany, NY USA
# No results found for OH United States
# No results found for Chicago
# No results found for Brandon, FL United States
# No results found for georgia
# No results found for Kansas City, MO
# No results found for Arlington, VA
# No results found for Greer, SC USA
# No results found for Carmel, IN United States
# No results found for Connelly, NY
# No results found for Miami, FL, USA.
# No results found for Boston, MA
# No results found for Harker Heights, TX
# No results found for Everett, WA USA
# No results found for IL
# No results found for NC, United States
# No results found for Washington State, USA
# No results found for New Orleans, LA  USA
# No results found for NYC
# No results found for Cincinnati, Ohio United States
# No results found for Ocean County, NJ
# No results found for Seattle, WA USA
# No results found for NY
# No results found for DC USA
# No results found for Los Angeles, CA United States
# No results found for st. louis, MO USA
# No results found for AL United States
# No results found for Chicago, IL
# No results found for Washington DC Area
# No results found for Coastal Maine
# No results found for Sherman Oaks, CA
# No results found for Des Moines, IA
# No results found for Brooklyn, NY, USA
# No results found for loma linda CA
# No results found for HORSHAM, PA United States
# No results found for Ventura, California
# No results found for San Jose, Ca United States
# No results found for Dallas, Texas
# No results found for Florida
# No results found for San Francisco, CA. USA
# No results found for Houston, TX USA
# No results found for PA
# No results found for Earth
# No results found for Mt. Pleasant, SC USA
# No results found for Montreal, Canada
# No results found for Saginaw, MI USA
# No results found for Holland
# No results found for Florida
# No results found for Illinois
# No results found for North Carolina
# No results found for Houston, TX United States
# No results found for Maine, USA
# No results found for Garland, TX USA
# No results found for Irvine, CA United States
# No results found for Bellevue, WA USA
# No results found for CHI PAR PHX SYD PDX CLD NKC
# No results found for Santa Monica, CA United States
# No results found for mpls
# No results found for arvada, co usa
# No results found for The United States of America
# No results found for Potomac Falls, VA
# No results found for Philadelphia, PA
# No results found for Princeton, NJ United States
# No results found for San Diego, CA
# No results found for Hamilton, Ohio United States
# No results found for Dallas, TX
# No results found for Bridgewater, NJ USA
# No results found for Clinton, NJ
# No results found for St. Louis
# No results found for San Francisco CA
# No results found for Alabama
# No results found for Seattle WA.
# No results found for AR
# No results found for New York
# No results found for Delaware United States
# No results found for GREENVILLE, SC USA
# No results found for Argentina
# No results found for hmm
# No results found for Seattle, WA United States
# No results found for Colorado, USA
# No results found for los angeles
# No results found for Simi Valley, CA United States
# No results found for Chicago, IL
# No results found for Chicago, IL
# No results found for Columbia, MS United States
# No results found for Ga
# No results found for safety harbor, fl United States
# No results found for Castle Rock, WA
# No results found for Burbank, Ca. USA
# No results found for North Carolina
# No results found for Seattle, WA USA
# No results found for Rockford, IL USA
# No results found for Reston, VA
# No results found for Scottsdale, AZ USA
# No results found for Grand Rapids, MI
# No results found for Michigan
# No results found for Burke, VA
# No results found for Chicago, IL USA
# No results found for Philadelphia PA
# No results found for San Francisco, CA
# No results found for southern Maine
# No results found for plano, texas
# No results found for Hayward, CA.
# No results found for Owensboro, KY
# No results found for new york
# No results found for Dallas, TX
# No results found for Detroit, MI
# No results found for US
# No results found for VT
# No results found for Fair Haven, New Jersey
# No results found for Phoenix, AZ
# No results found for Manassas, VA United States
# No results found for SC, USA
# No results found for Bethlehem, PA United States
# No results found for Chicago, IL USA
# No results found for Baton Rouge, LA
# No results found for USA
# No results found for walnut, ca
# No results found for Greenville, SC
# No results found for Houston, TX
# No results found for Farmington Hills, Michigan
# No results found for Los Angeles, CA
# No results found for Nashua, NH United States
# No results found for CT
# No results found for Boston, MA
# No results found for Morristown, NJ United States
# No results found for Manassas, VA United States
# No results found for Northern Virginia
# No results found for LA
# No results found for Morristown, TN
# No results found for Washington, DC
# No results found for Sweden, Europe
# No results found for Murphy, Oregon, USA
# No results found for Indiana
# No results found for Caracas, VE
# No results found for Chile
# No results found for Flagstaff, AZ
# No results found for Fountain, CO United States
# No results found for Point Reyes Station, CA United States
# No results found for New York, NY
# No results found for San Francisco,  USA
# No results found for NYC, NY, USA
# No results found for burbank, california United States
# No results found for Frankfort, KY USA
# No results found for Apo, Ap United States
# No results found for Phoenix, Az
# No results found for Severn Maryland
# No results found for Michigan
# No results found for San Francisco, CA United States
# No results found for Durham, NC, United States
# No results found for Fayetteville, AR USA
# No results found for Livermore, CA USA
# No results found for Sao Paulo, SP BR
# No results found for West Coast
# No results found for So. Calif.
# No results found for TX
# No results found for Pennsylvania.
# No results found for Hummelstown, PA United States
# No results found for Traveling
# No results found for Cincinnati
# No results found for Chicago, IL
# No results found for Seattle, WA USA
# No results found for Raleigh, NC
# No results found for Maryland, US
# No results found for San Jose, Costa Rica
# No results found for Washington, DC
# No results found for Roanoke, TX United States
# No results found for California
# No results found for Ohio, USA
# No results found for Lenox, MA
# No results found for santo domingo,DR
# No results found for United States
# No results found for UT
# No results found for charlotte,nc
# No results found for Cerritos, CA
# No results found for SF Bay Area, CA United States
# No results found for Atlanta, GA.
# No results found for TENNESSEE USA
# No results found for Riverside, CA USA
# No results found for Ann Arbor, Michigan
# No results found for West Hartford, CT
# No results found for Fayetteville, AR USA
# No results found for Beaverton, OR United States
# No results found for Marshall, MN United States
# No results found for USA
# No results found for UT
# No results found for England UK
# No results found for Los Angeles, CA
# No results found for CNY
# No results found for West Palm Beach, FL
# No results found for Lakewood, CO USA
# No results found for USA
# No results found for Baltimore, MD
# No results found for Kansas City, MO USA
# No results found for San Diego, California United States
# No results found for NY
# No results found for Woodbridge, VA USA
# No results found for Zanesville, Ohio
# No results found for Humble, TX
# No results found for Lawrenceville, Georgia United States
# No results found for New York
# No results found for TN
# No results found for Tennessee
# No results found for California: LA, U.S.A.
# No results found for Freeport Bahamas
# No results found for Algonquin, IL United States
# No results found for Toronto, Canada
# No results found for TX USA
# No results found for USA
# No results found for Phoenixville,PA
# No results found for Central U.S.
# No results found for Lowell, OR USA
# No results found for Tokyo JAPAN
# No results found for Wiesbaden, Hessen Germany
# No results found for Malibu, CA USA
# No results found for Troy, MI USA
# No results found for Manhattan, New York
# No results found for Laramie, WY USA
# No results found for the same planet as you.
# No results found for Seattle, Wa
# No results found for Wauwatosa, WI USA
# No results found for Midwest
# No results found for Aberdeen, WA United States
# No results found for La Mesa ,CA United States
# No results found for Atlantic Beach, FL United States
# No results found for Cupertino, CA
# No results found for Chicago, IL
# No results found for Smithfield VA
# No results found for Washington, DC
# No results found for Newport Beach, CA
# No results found for Flushing, NY United States
# No results found for New Milford, New Jersey
# No results found for Tallahassee, Florida United States
# No results found for Illinois
# No results found for Dayton
# No results found for Berkeley, CA United States
# No results found for NC
# No results found for Wichita, KS USA
# No results found for Muskego, WI USA
# No results found for Shingle Springs, CA USA
# No results found for Shanghai, China
# No results found for Portland OR. area
# No results found for Wash., D.C. Metro
# No results found for Ohio USA
# No results found for Erie, PA, USA, Earth
# No results found for California
# No results found for Chino, CA United States
# No results found for Portland, OR USA
# No results found for Plano, TX United States
# No results found for Gilroy, CA USA
# No results found for CA
# No results found for Surf City, California & Eagle, Colorado
# No results found for San Antonio, TX
# No results found for WILLISVILLE
# No results found for U.S.A.
# No results found for Florida
# No results found for pleasant grove, al United States
# No results found for Lenexa, Kansas United States
# No results found for Somewhere in Arizona
# No results found for Kansas City, MO
# No results found for Fort Lauderdale, FL USA
# No results found for Budapest, Hungary
# No results found for eastern Pennsylvania
# No results found for eastern oregon
# No results found for CA, United States
# No results found for Morgan, UT
# No results found for Elko, MN
# No results found for Middletown, Delaware United States
# No results found for Jacksonville, FL USA
# No results found for San Diego,m CA
# No results found for GA
# No results found for Beverly Hills, CA USA
# No results found for Santa Monica, CA United States
# No results found for Minneapolis, MN USA
# No results found for Spain
# No results found for Boston, MA United States
# No results found for San Diego, CA
# No results found for San Antonio, TX USA
# No results found for Central  New Jersey United States
# No results found for Burtonsville, Md.
# No results found for Canada
# No results found for Fairfax, VA
# No results found for Yonkers, NY USA
# No results found for Fontana, CA. USA
# No results found for Marco Island, Florida United States
# No results found for Phoenix, Az, USA
# No results found for Chicago, IL, USA
# No results found for Stillwater, OK United States
# No results found for Berlin, GERMANY
# No results found for Denver, co
# No results found for Saint Louis, MO
# No results found for Austin Tx
# No results found for Lansing, Mi United States
# No results found for New York Metro Area
# No results found for New York, NY
# No results found for Mililani Town, HI United States
# No results found for Toronto, CA
# No results found for Bakersfield, CA
# No results found for New York
# No results found for United States
# No results found for Charlotte, NC
# No results found for katy, tx United States
# No results found for Hudsonville, Michigan
# No results found for Perth Amboy, NJ, USA
# No results found for Toronto, ON Canada
# No results found for Boulder, CO USA
# No results found for Seattle, WA  USA
# No results found for media, pa United States
# No results found for Florence, MA United States
# No results found for Russell,PA
# No results found for Idaho - Hawaii
# No results found for Detroit MI
# No results found for Lutz FL
# No results found for New Jersey
# No results found for SC USA
# No results found for NB, Canada
# No results found for Maracaibo, Venezuela
# No results found for CA USA
# No results found for APO, AE USA
# No results found for California, USA
# No results found for Homosassa, FL United States
# No results found for Maryland, USA
# No results found for RTP, NC USA
# No results found for San Jose, CA USA
# No results found for New Jersey
# No results found for Redwood Shores, CA United States
# No results found for Winthrop, MA United States
# No results found for Ohio
# No results found for Mequon WI United States
# No results found for Big Cove, AL USA
# No results found for Seattle, WA USA
# No results found for Kansas
# No results found for New Brunswick, NJ, USA
# No results found for Felton, CA
# No results found for Fairfax, VA USA
# No results found for Washington, DC
# No results found for Rainbow City, AL USA
# No results found for Orangeburg, SC United States
# No results found for California
# No results found for San Francisco, California
# No results found for Honolulu, HI
# No results found for kuwait
# No results found for lawrence, ks
# No results found for Bradenton, Fl USA
# No results found for Belmont, Ma United States
# No results found for Berkeley CA
# No results found for Glenview, IL United States
# No results found for PA USA
# No results found for Winter Park, FL USA
# No results found for USA
# No results found for Milford, OH USA
# No results found for California
# No results found for Daytona Beach, Florida
# No results found for Phoenix
# No results found for PA USA
# No results found for Glendale, AZ USA
# No results found for Denver, CO USA
# No results found for KEW GARDENS, NY United States
# No results found for St. Louis, MO United States
# No results found for Catonsville, Maryland United States
# No results found for Venezuela
# No results found for canada
# No results found for U.S.A
# No results found for East Setauket, New York United States
# No results found for orlando,florida
# No results found for Bloomington, IN USA
# No results found for Braceville, Oh
# No results found for wyoming
# No results found for Wisconsin
# No results found for Mars
# No results found for Beautiful Michigan
# No results found for Electric City, NY United States
# No results found for Torrance, CA USA
# No results found for All over the US
# No results found for Boston,MA
# No results found for Downey, CA USA
# No results found for san mateo, ca
# No results found for In the world
# No results found for Georgia
# No results found for Atlanta, GA
# No results found for New York, NY
# No results found for Jonesboro, GA USA
# No results found for NY, NY
# No results found for New York
# No results found for San Francisco, CA United States
# No results found for Atlanta, GA USA
# No results found for Harrisburg, PA United States
# No results found for austin
# No results found for Michigan, USA
# No results found for Utah
# No results found for Whittier, Alaska USA
# No results found for Houston, Texas
# No results found for East Lansing, MI United States
# No results found for Atlanta, GA United States
# No results found for MDI Maine, USA
# No results found for NY
# No results found for Cleveland, OH USA
# No results found for Brewster, New York United States
# No results found for St. Louis
# No results found for Pasadena, CA USA
# No results found for Jacksonville, FL
# No results found for Beautiful Portland
# No results found for DAYTON, OHIO
# No results found for California
# No results found for Cincinnati
# No results found for PA. USA
# No results found for Winchester, VA
# No results found for Palm Desert, CA United States
# No results found for USA
# No results found for Arlington, Texas USA
# No results found for Scottsdale, AZ
# No results found for San Diego, CA United States
# No results found for Maryland USA
# No results found for Alameda, CA United States
# No results found for Geln Allen VA USA
# No results found for Palm Springs, Ca USA
# No results found for Iowa
# No results found for Reno, NV
# No results found for Caracas, Venezuela
# No results found for Rep. Dom
# No results found for California
# No results found for Yuba City, CA.
# No results found for Dallas,TX
# No results found for Michigan
# No results found for Mesquite, Tx United States
# No results found for WINDSOR, CT USA
# No results found for Dallas, TX USA
# No results found for Tucson, AZ
# No results found for LA, CA, USA
# No results found for Milwaukee, WI
# No results found for Stanely, NC United States
# No results found for Atlanta, GA
# No results found for Louisville, KY
# No results found for Saint Augustine, FL
# No results found for NC  USA
# No results found for Redlands , CA
# No results found for United States
# No results found for S. Cal. USA
# No results found for Detroit, MI
# No results found for California. USA
# No results found for Conklin, NY USA
# No results found for Mt. Clemens, MI
# No results found for across the street
# No results found for Miami, Florida
# No results found for West Lebanon, NH USA
# No results found for Chicago, IL
# No results found for Pittsburgh, PA United States
# No results found for NJ, USA
# No results found for Virginia USA
# No results found for Arizona
# No results found for Countryside, IL United States
# No results found for Seattle WA
# No results found for The Woodlands, Tx United States
# No results found for Texas
# No results found for Illinois
# No results found for Ann Arbor, MI
# No results found for St. Petersburg, FL United States
# No results found for Fort Worth
# No results found for Minnesota USA
# No results found for Brandon, FL
# No results found for OH
# No results found for Dallas, Tx
# No results found for Golden, CO United States
# No results found for Middlesboro, KY USA
# No results found for Brooklyn, NY
# No results found for San Diego, CA
# No results found for Portland, OR USA
# No results found for Hollywood
# No results found for Seattle WA
# No results found for Ashburn, VA USA
# No results found for Vermont
# No results found for Los Angeles, CA USA
# No results found for CA
# No results found for UT
# No results found for New Jersey
# No results found for Austin, TX USA
# No results found for Austin, TX United States
# No results found for Trinidad
# No results found for Orange County
# No results found for OCEANSIDE, CALIFORNIA United States
# No results found for Metro DC
# No results found for Santo Domingo, Dominican Republic
# No results found for Mercer Island, WA USA
# No results found for San Francisco, CA
# No results found for Chicago, IL United States
# No results found for Fountain, CO United States
# No results found for Point Reyes Station, CA United States
# No results found for Chicago, IL USA
# No results found for Greensboro NC
# No results found for Atlantic Beach, FL United States
# No results found for Maryland
# No results found for Roanoke, TX United States
# No results found for Seattle, WA USA
# No results found for Adirondacks
# No results found for Cincinnati, OH USA
# No results found for Michigan
# No results found for Lancaster, CA.    USA
# No results found for California
# No results found for florida
# No results found for Geneva, IL  USA
# No results found for SC, USA
# No results found for KS
# No results found for Endicott, NY USA
# No results found for Whittier, CA USA
# No results found for Houghton, New York USA
# No results found for Austin, Tx United States
# No results found for Rahway, New Jersey USA
# No results found for Dallas, TX USA
# No results found for New York
# No results found for New York
# No results found for Laramie, WY United States
# No results found for Lewisburg, PA USA
# No results found for RI
# No results found for LOS ANGELES, CA
# No results found for Thonotosassa, FL USA
# No results found for DFW, TX
# No results found for Virginia
# No results found for Ventura, CA
# No results found for Hills of Tennessee
# No results found for Palo Alto, CA USA
# No results found for Khartoum, Sudan
# No results found for Jerusalem, Israel
# No results found for Idaho
# No results found for Buffalo, NY USA
# No results found for New York State
# No results found for Omaha, NE
# No results found for Monterey,CA,USA
# No results found for Washington, DC
# No results found for Lawrenceville N.J.
# No results found for Ambler, PA United States
# No results found for Los Angeles, CA United States
# No results found for OHIO
# No results found for Dayton, OH USA
# No results found for houston, tx United States
# No results found for Atlanta, GA  USA
# No results found for Ohio
# No results found for Atlanta, Georgia
# No results found for Ashdod, Israel
# No results found for Melbourne, Australia
# No results found for Northern CA
# No results found for Oregon
# No results found for St. Louis
# No results found for Stockbridge, MA United States
# No results found for Davenport Ia USA
# No results found for Byram, CT USA
# No results found for Pico Rivera, CA United States
# No results found for Farmland USA
# No results found for New York
# No results found for USA
# No results found for CRC
# No results found for Olney, Ill.
# No results found for Los Angeles, CA USA
# No results found for Iasi, Romania
# No results found for USA
# No results found for FL USA
# No results found for North Georgia
# No results found for Fountain Hills, Arizona
# No results found for Brewster, NY
# No results found for Los Altos Hills, CA USA
# No results found for New Jersey
# No results found for NJ, USA
# No results found for California, United States
# No results found for Blaine, MN USA
# No results found for NJ
# No results found for Seattle WA
# No results found for Los Angeles, CA
# No results found for Purcellville, VA United States
# No results found for Winter Haven, FL USA
# No results found for San Francisco CA USA
# No results found for Huntington Beach, CA
# No results found for Santa Clara , CA
# No results found for Houston
# No results found for San Francisco, CA USA
# No results found for Madison WI usa
# No results found for Dunwoody, GA United States
# No results found for Las Cruces, NM USA
# No results found for Sunnydale, CA
# No results found for Florida
# No results found for Live Oak, FL USA
# No results found for Northern Virginia, USA
# No results found for Potter Valley, CA
# No results found for Racine, WI USA
# No results found for Denver, Colorado
# No results found for San Diego, CA United States
# No results found for Albuquerque, NM
# No results found for Apple Creek, OH.
# No results found for Chicago, IL USA
# No results found for NY
# No results found for West Palm Beach, FL
# No results found for Philadelphia, PA  USA
# No results found for Texas
# No results found for Texas
# No results found for Bluffton, OH
# No results found for Bosque Farms, NM
# No results found for Redding, CA
# No results found for Silicon Valley, CA
# No results found for Germany,  US Armed Forces
# No results found for Texas
# No results found for Marquette, MI USA
# No results found for Little Rock, Arkansas United States
# No results found for Maryland,USA
# No results found for Austin, TX USA
# No results found for Los Angeles, CA
# No results found for indianapolis, indiana United States
# No results found for Los Angeles, CA, United States
# No results found for Olympia, WA
# No results found for Cambridge, MA USA
# No results found for Norway
# No results found for San Jose, CA USA
# No results found for earth
# No results found for Miami, FL USA
# No results found for CA
# No results found for NY, NY
# No results found for New England, USA
# No results found for Texas
# No results found for Nicosia,  Cyprus
# No results found for KY
# No results found for Bethesda, MD USA
# No results found for Amsterdam,  Netherlands
# No results found for Utah
# No results found for Oslo, Norway
# No results found for Seattle, WA
# No results found for Gastonia, NC USA
# No results found for Seattle, WA United States
# No results found for usa
# No results found for Earth
# No results found for USA
# No results found for Orange City Fl
# No results found for Central Texas
# No results found for Texas
# No results found for Canton, MI United States
# No results found for new jersey, USA
# No results found for Cabo San Lucas, Mexico
# No results found for Phoenix, Arizona
# No results found for Chicago, IL
# No results found for Houston, TX
# No results found for Ft Lauderdale, Florida USA
# No results found for across the street
# No results found for Woodbury, CT USA
# No results found for Brooklyn, NY
# No results found for North Carolina, NC USA
# No results found for Tucson, AZ United States
# No results found for JERMYN, PA
# No results found for NJ
# No results found for Houston, TX United States
# No results found for Indiana
# No results found for New Jersey
# No results found for Jacksonville, FL USA
# No results found for new york, ny USA
# No results found for Shreveport, LA
# No results found for Los Angeles
# No results found for Dallas, Texas
# No results found for Greensboro, GA USA
# No results found for atlanta, ga, usa
# No results found for United States
# No results found for Cambridge, MA
# No results found for OH
# No results found for Winter Haven, FL USA
# No results found for Connecticut, USA
# No results found for Seattle, WA
# No results found for NJ
# No results found for Allentown, PA United States
# No results found for Caracas, DC, VE
# No results found for Pensacola, FL USA
# No results found for Detroit, MI
# No results found for Minnesota
# No results found for Brighton, MI USA
# No results found for new york
# No results found for Eagle, CO USA
# No results found for Dobbs Ferry, NY USA
# No results found for SA
# No results found for Philadelphia, PA USA
# No results found for usa
# No results found for United States
# No results found for New Jersey
# No results found for Huntsville, Alabama USA
# No results found for Panama City, FL USA
# No results found for Portsmouth, NH
# No results found for san diego
# No results found for New York, NY USA
# No results found for humid Miami FL
# No results found for California
# No results found for Sacramento, Ca
# No results found for Dearborn Michigan
# No results found for Eastern Washington
# No results found for Illinois
# No results found for Phoenix, AZ USA
# No results found for Virginia, USA
# No results found for Palo Alto, CA United States
# No results found for Marquette, MI
# No results found for Minnesota USA
# No results found for Montgomery, NY USA
# No results found for Milford, OH USA
# No results found for Ca, USA, Earth
# No results found for Canton, Ohio USA
# No results found for Benson, VT
# No results found for Vestavia Hills, AL USA
# No results found for California
# No results found for MICHIGAN, USA
# No results found for Switzerland
# No results found for Oklahoma
# No results found for Houston, TX
# No results found for San Antonio, Texas United States
# No results found for VanWa
# No results found for Parkland, FL USA
# No results found for New York
# No results found for Arlington, MA United States
# No results found for PA
# No results found for missouri
# No results found for St. Louis, MO
# No results found for Louisiana
# No results found for Germantown, MD USA
# No results found for massachusetts
# No results found for Vermont
# No results found for FL
# No results found for Bay Area, CA
# No results found for Salem, Oregon
# No results found for Portland, Oregon
# No results found for Palm Coast, FL United States
# No results found for Atlantic Beach, FL United States
# No results found for Grand Prairie, TX USA
# No results found for DC, USA
# No results found for Charlotte, NC USA
# No results found for Kentucky
# No results found for From Where, Me Thinks It Matters Not!
# No results found for North Carolina
# No results found for Seattle, WA USA
# No results found for NM
# No results found for dansville, ny usa
# No results found for Texas
# No results found for south Florida, U.S.A.
# No results found for San Jose, CA
# No results found for Boston, MA
# No results found for Newark, DE United States
# No results found for Brooklyn, NY United States
# No results found for Turkey
# No results found for seaside,oregon
# No results found for Boston, MA USA
# No results found for San Francisco, USA
# No results found for IN, USA
# No results found for Mendocino COunty, California
# No results found for New York
# No results found for Boston, MA United States
# No results found for NJ, USA
# No results found for Minnesota, USA
# No results found for New York, NY
# No results found for MO
# No results found for Hollywood, CA
# No results found for Ann Arbor, MI USA
# No results found for La Luz, NM
# No results found for USA
# No results found for Naperville, IL United States
# No results found for same world as you
# No results found for Florida
# No results found for Erie, PA United States
# No results found for NY, USA
# No results found for Rhode Island
# No results found for Albany, NY
# No results found for Ventura, CA, United States
# No results found for Massachusetts
# No results found for Bremerton, WA USA
# No results found for Ashburn, VA USA
# No results found for San Diego
# No results found for Jackson, TN
# No results found for Minneapolis, MN
# No results found for Goodyear, AZ United States
# No results found for San Diego, CA USA
# No results found for MEX
# No results found for Dallas, Texas
# No results found for Jeddah, Saudi Arabia
# No results found for Mammoth Lakes, CA USA
# No results found for Tampa, Florida USA
# No results found for Boston, MA
# No results found for San Diego, CA
# No results found for California
# No results found for sonoma, ca
# No results found for Minnesota!
# No results found for Moose Island, Maine
# No results found for Madison, WI
# No results found for San Antonio, TX USA
# No results found for Fl, USA
# No results found for new jersey
# No results found for Detroit Michigan
# No results found for Los Angeles,CA, USA
# No results found for San Francisco, CA USA
# No results found for Kingston, Jamaica
# No results found for Los Alamos, New Mexico
# No results found for chicago
# No results found for NY
# No results found for Walton, KY United States
# No results found for SAN FRANCISCO, CA USA
# No results found for Olney, Maryland USA
# No results found for Frederick, MD
# No results found for a galaxy, far, far away...
# No results found for Wilmington, DE
# No results found for Charleston, SC
# No results found for Buffalo, NY
# No results found for Copiague, NY United States
# No results found for Pittsburgh, PA USA
# No results found for FL
# No results found for Florence, OR USA
# No results found for Rochester, NY
# No results found for Taos, NM, USA
# No results found for Louisville, KY
# No results found for Campbell, CA USA
# No results found for Nebraska
# No results found for Pennsylvania
# No results found for Colorado Springs
# No results found for Columbia, MD
# No results found for Philadelphia, PA
# No results found for Chicago
# No results found for NY State
# No results found for Massachusetts
# No results found for Palmdale, CA USA
# No results found for Washington, DC United States
# No results found for CA
# No results found for Michigan
# No results found for CA United States
# No results found for San Diego, CA USA
# No results found for FRESNO,CA.
# No results found for Brooklyn, NY
# No results found for PA - United States
# No results found for Washington County, Missouri
# No results found for N.  VA USA
# No results found for Orlando,FL
# No results found for Atlanta, GA
# No results found for Los Angeles, CA, formerly Rochester, MN USA
# No results found for Santa Monica, CA
# No results found for Kuwait
# No results found for Pittsburgh
# No results found for NY, USA
# No results found for Florida, USA
# No results found for New York
# No results found for Brazil
# No results found for Paradise, CA United States
# No results found for Utah, USA
# No results found for La Puente, CA, USA
# No results found for New Jersey
# No results found for Netherlands
# No results found for San Diego, CA
# No results found for Philadelphia, PA
# No results found for Youngstown, NY USA
# No results found for usa
# No results found for US
# No results found for Indiana
# No results found for San Antonio TX
# No results found for From neither here nor there
# No results found for Chicago, IL United States
# No results found for Tellico Plains, TN United States
# No results found for Setauket, NY
# No results found for Hopkinton, MA USA
# No results found for Kingsville, MD.
# No results found for New Jersey
# No results found for TL WA
# No results found for Sault Ste. Marie, Canada
# No results found for Montana
# No results found for Fairfax, VA USA
# No results found for TX, US
# No results found for B.Lo, NY
# Error fetching location info for Sugar Grove, Ohio,USA: Expecting value: line 1 column 1 (char 0)
# No results found for USA
# No results found for San Diego, CA
# No results found for Kirkland, WA United States
# No results found for Keizer, OR
# No results found for Orlando, Florida  USA
# No results found for Red Lake, Ontario / Mound City, KS
# No results found for Houston, TX
# No results found for Los Angeles, CA
# No results found for Tampa Bay, Florida
# No results found for Oxnard, CA USA
# No results found for Ontario, Canada
# No results found for Utah
# No results found for ohio
# No results found for Deland, Fl United States
# No results found for USA
# No results found for Stockton, CA
# No results found for Knoxville, Tennessee
# No results found for Maryland
# No results found for Williamsburg, Va
# No results found for Stroudsburg, PA United States
# No results found for Atlanta, GA
# No results found for Las Vegas, NV USA
# No results found for Fort Myers, FL
# No results found for USA
# No results found for Los Angeles, CA
# No results found for Gorham, ME USA
# No results found for New York, NY
# No results found for MIlwaukee,WI
# No results found for Seattle, WA
# No results found for Port Angeles, WA USA
# No results found for Albuquerque
# No results found for USA
# No results found for Upper West Side, New York, New York United States
# No results found for Marshall,WI
# No results found for St. Augustine, Florida USA
# No results found for Londonderry, NH
# No results found for New England
# No results found for Carmel, CA USA
# No results found for Bowie, MD United States
# No results found for Melbourne, Australia
# No results found for Los Angeles, CA
# No results found for PA
# No results found for toronto,canada
# No results found for The Southern U.S.
# No results found for Richmond, VA United States
# No results found for Gales Ferry, CT
# No results found for Rochester, NY USA
# No results found for Seattle, WA
# No results found for Atlanta, GA USA
# No results found for SLC
# No results found for KALAMAZOO, MICHIGAN United States
# No results found for St. Peters, Missouri
# No results found for Los Angeles, CA USA
# No results found for Rockford, IL USA
# No results found for Antioch, CA United States
# No results found for Reno, NV United States
# No results found for South Florida
# No results found for Jacksonville, FL
# No results found for California
# No results found for Saint Louis, MO USA
# No results found for ohio
# No results found for Monroe, La
# No results found for Colorado Springs, CO United States
# No results found for Clearwater, Fl
# No results found for Junction City, KS
# No results found for san francisco
# No results found for Sao Paulo, SP Brazil
# No results found for Florida
# No results found for Texas USA
# No results found for NY
# No results found for Portland, OR USA
# No results found for Barbados
# No results found for Caracas, DC Venezuela
# No results found for Arizona, USA
# No results found for Virginia
# No results found for Michigan City, Indiana USA
# No results found for Lincoln City, OR USA
# No results found for London
# No results found for Thibodaux, Louisiana United States
# No results found for Uxbridge, MA
# No results found for Louisville, Kentucky United States
# No results found for Somerville, MA
# No results found for Texas, USA
# No results found for San Francisco
# No results found for New York, NY
# No results found for West Texas Native
# No results found for Kansas
# No results found for Arizona
# No results found for WV, USA
# No results found for Oakland, CA
# No results found for Ct
# No results found for Guatemala, Guatemala
# No results found for Denver, CO
# No results found for Boston MA USA
# No results found for Boston MA USA
# No results found for Chicago, IL, USA
# No results found for Stillwater, OK United States
# No results found for Berlin, GERMANY
# No results found for Denver, co
# No results found for Sao Jose dos Campos, Sao Paulo Brazil
# No results found for Yorktown Heights, NY United States
# No results found for Springdale, AR USA
# No results found for brooklyn, ny
# No results found for Australia
# No results found for Princeton, NJ
# No results found for Los Angeles, CA United States
# No results found for Rome, NY USA
# No results found for Bloomsburg, PA United States
# No results found for Chicago IL USA
# No results found for XavierSchool, ForGifted, Children
# No results found for Houston, TX
# No results found for Dallas, TX
# No results found for New Mexico
# No results found for Oakland, CA
# No results found for NY, NY
# No results found for Brackenridge, PA  USA
# No results found for Houston, Texas
# No results found for Maryland
# No results found for Phoenix, Az
# No results found for pa, usa
# No results found for Sheboygan, WI
# No results found for Beaver Falls, PA
# No results found for Long Island, NY
# No results found for Los Angeles, CA USA
# No results found for The Show Me State
# No results found for Southern CA United States
# No results found for Oakland, CA USA
# No results found for Detroit, MI (USA
# No results found for Jackson, MS
# No results found for Pleasant Hill, CA United States
# No results found for Chattanooga, TN United States
# No results found for St. Petersburg, FL United States
# No results found for Costa Rica
# No results found for Ravenna, MI United States
# No results found for Cabimas, ZU Venezuela
# No results found for Detroit
# No results found for NY, USA
# No results found for Colorado USA
# No results found for Springfield, Ohio
# No results found for SF CA
# No results found for CA
# No results found for Parkville, Maryland United States
# No results found for Torrance, CA USA
# No results found for Long Island, NY USA
# No results found for Santa Barbara, CA
# No results found for California
# No results found for Martinsburg, WV USA
# No results found for Oxnard, CA United States
# No results found for Richardson, TX USA
# No results found for Wash., D.C. Metro
# No results found for Washington DC
# No results found for Littleton, Co United States
# No results found for Torrance, CA USA
# No results found for Gilroy, CA USA
# No results found for Gainesville, FL USA
# No results found for Guatemala, Guatemala City
# No results found for Orange, CA
# No results found for Dilbert's World, ME
# No results found for DC
# No results found for Jacksonville, FL
# No results found for Paris, Ontario Canada
# No results found for Pa. USA
# No results found for Ohio
# No results found for The Caribbean
# No results found for Salt Lake City, UT
# No results found for Staten island, NY
# No results found for New York City
# No results found for Los Angeles, CA USA
# No results found for Sydney, Australia
# No results found for nyc , ny United States
# No results found for Algonquin, IL United States
# No results found for Oklahoma
# No results found for New Orleans
# No results found for Here, USA
# No results found for Phoenix, AZ USA
# No results found for Boston, MA USA
# No results found for last one turn out the lights in Michigan
# No results found for San Diego, CA United States
# No results found for ILLINOIS
# No results found for NY
# No results found for St. Augustine, Florida United States
# No results found for Sherman Oaks California
# No results found for NY
# No results found for Seaford, NY
# No results found for Bellmore Long Island
# No results found for East TN
# No results found for Spotsylvania, VA USA
# No results found for New York, NY USA
# No results found for La Jolla, CA United States
# No results found for Iraq
# No results found for St. Louis, MO USA
# No results found for Millington, NJ United States
# No results found for Connecticut, USA
# No results found for Denver, CO
# No results found for Park Ridge, Illinois United States
# No results found for Oregon
# No results found for Agoura Hills, CA
# No results found for Florida
# No results found for Brooklyn, New York
# No results found for Indianapolis, IN
# No results found for NJ USA
# No results found for New Jersey, USA
# No results found for Bogota, Colombia
# No results found for New York, NY
# No results found for CA
# No results found for Cleveland,  OH USA
# No results found for Baltimore, MD USA
# No results found for Atlanta, GA
# No results found for San Francisco, CA
# No results found for Sydney, NSW Australia
# No results found for Central Valley, CA
# No results found for Brighton, MI USA
# No results found for Chicago
# No results found for Bristol, CT
# No results found for Glasgow, Scotland
# No results found for Columbus  OH
# No results found for Arizona
# No results found for Ct.  USA
# No results found for San Francisco
# No results found for RS, Brazil
# No results found for pennsylvania United States
# No results found for Kentucky
# No results found for Fresno, CA USA
# No results found for USA
# No results found for Detroit, MI
# No results found for San Carlos, CA USA
# No results found for Ma
# No results found for southern sunshine
# No results found for New York City
# No results found for San Diego, CA USA
# No results found for Flagstaff, AZ
# No results found for Vidor, TX United States
# No results found for Alamo, CA USA
# No results found for Mexico City
# No results found for california
# No results found for Alabama, USA
# No results found for Parker, CO USA
# No results found for Chicago, IL
# No results found for Los Angeles, CA United States
# No results found for San Francisco, CA
# No results found for Seattle, WA USA
# No results found for Norman, OK United States
# No results found for Miller Place, NY USA
# No results found for San Antonio, TX
# No results found for USA
# No results found for ct, USA
# No results found for Michigan USA
# No results found for sps, hn
# No results found for chico, ca
# No results found for USA
# No results found for Reno, NV USA
# No results found for Illinois
# No results found for Phoenix
# No results found for Chicago
# No results found for New York, NY
# No results found for Lodi , CA
# No results found for USA, but he is not my president
# No results found for Dover, DE USA
# No results found for Arkansas
# No results found for High Point, NC USA
# No results found for usa
# No results found for Powell, TN, USA
# No results found for Hilo, Hawaii
# No results found for Fort Worth, Tx
# No results found for Olney, Md.
# No results found for NY
# No results found for Los Angeles, CA United States
# No results found for Seattle, Washington
# No results found for NORTHRIDGE, CA USA
# No results found for Kingston, MA
# No results found for Draper, UT United States
# No results found for Ft. Worth, Tx USA
# No results found for NYS
# No results found for Ft Lauderdale, FL USA
# No results found for Brooklyn, NY USA
# No results found for texas
# No results found for Staten Island, New York
# No results found for Portland, OR
# No results found for Miami FL
# No results found for Los Angeles, CA
# No results found for Kings Park, NY USA
# No results found for Pok,  New York
# No results found for Atlanta, GA
# No results found for Akron, Ohio
# No results found for CT, USA
# No results found for Bay Area, California
# No results found for California
# No results found for Barstow, CA United States
# No results found for Kansas USA
# No results found for NH United States
# No results found for redmond, wa United States
# No results found for Coral Springs, FL
# No results found for PURDUE!!!
# No results found for Pittsburgh, PA United States
# No results found for Medford Lakes, NJ USA
# No results found for Barre, MA USA
# No results found for VA-USA
# No results found for Buffalo, NY
# No results found for California
# No results found for USA
# No results found for Boston, Ma United States
# No results found for Cambridge, MA USA
# No results found for Chicago, IL USA
# No results found for Houma, LA
# No results found for U.S.
# No results found for Hebron, CT USA
# No results found for Moab, UT
# No results found for HAINESPORT NEW JERSEY
# No results found for Loves Park, IL
# No results found for San Diego, CA USA
# No results found for North Pole, AK
# No results found for Southeast USA
# No results found for Brooklyn, NY United States
# No results found for Northern California
# No results found for Stillwater, OK United States
# No results found for San Francisco, CA United States
# No results found for Saddle River, NJ USA
# No results found for Mesa, Arizona
# No results found for Phoenix, AZ
# No results found for Portland Maine
# No results found for Orlando, FL United States
# No results found for Louisiana
# No results found for Portland Or
# No results found for Cary, NC
# No results found for New York NY
# No results found for Houston, TX
# No results found for Boca Raton, FL USA
# No results found for New Hampshire
# No results found for Indianapolis, IN USA
# No results found for USA
# No results found for Brandon, Florida
# No results found for Silver Spring, MD USA
# No results found for Washington, DC
# No results found for Miami, FL
# No results found for Renton, Wa United States
# No results found for Grabill, IN United States
# No results found for Bama
# No results found for USA
# No results found for West Valley City, Utah United States
# No results found for San Diego CA USA
# No results found for Medford, MA USA
# No results found for Ocala, FL USA
# No results found for Saint Louis, MO United States
# No results found for Taylorsville, Indiana
# No results found for Michigan, USA
# No results found for Waterford, MI
# No results found for Snoqualmie, WA United States
# No results found for Austin, Tx USA
# No results found for Fairbanks, Alaska USA
# No results found for Salt Lake City, UT USA
# No results found for Seattle, WA United States
# No results found for Fresno, CA USA
# No results found for Bay Area, CA
# No results found for VA, USA
# No results found for Indianapolis, IN USA
# No results found for Chicago
# No results found for Waldorf, MD
# No results found for Twin Cities, MN USA
# No results found for cheyenne, wyoming United States
# No results found for Hamilton, NJ United States
# No results found for Newark, DE
# No results found for portsmouth, nh
# No results found for istanbul Turkey
# No results found for San Diego, CA  USA
# No results found for Carbondale, IL
# No results found for Prior Lake, MN United States
# No results found for Washington State USA
# No results found for Hastings-on-Hudson, NY United States
# No results found for Monticello, NY
# No results found for Denver
# No results found for IL USA
# No results found for PA
# No results found for New York
# ...
# No results found for Sacramento, CA
# No results found for Anchorage, Alaska United States
# No results found for Cambridge, MA USA
# No results found for Wayne, NJ United States
# No results found for Hawaii
# No results found for Reynoldsburg, OH USA
# No results found for St. Louis, MO
# No results found for San Antonio, TX USA
# No results found for USA
# No results found for Los Angeles, Ca
# No results found for New Hampshire
# No results found for Henderson, KY USA
# No results found for Kansas
# No results found for Dublin, OH United States
# No results found for london, uk
# No results found for Leesburg, OH USA
# No results found for Inside the jar...
# No results found for Croatia
# No results found for Corona, CA United States
# No results found for NJ USA
# No results found for BATON ROUGE, LA USA
# No results found for Maryland
# No results found for Kentucky United States
# No results found for Greenville SC
# No results found for Tacoma, Washington
# No results found for Hammond, IN USA
# No results found for THE ENTERTAINMENT REPORT (ALAN W. PETRUCELLI
# No results found for Colorado
# No results found for russianwriter.net
# No results found for Elmhurst, Illinois United States
# No results found for Brooklyn, NY
# No results found for USA, NC
# No results found for Newburgh, IN USA
# No results found for Auburn, WA  USA
# No results found for San Antonio, Texas United States
# No results found for Los Angeles, CA USA
# No results found for San Ramon, CA
# No results found for Pennsylvania
# No results found for New York
# No results found for London, England
# No results found for Baltimore
# No results found for Atlanta, Georgia
# No results found for Boise, ID
# No results found for Out there in La La Land
# No results found for Wayland, NY
# No results found for Des Moines, WA
# No results found for DC
# No results found for Philadelphia,PA USA
# No results found for USA
# No results found for San Francisco, CA United States
# No results found for South Central PA, USA
# No results found for New Englnd
# No results found for Texas
# No results found for Provincetown, MA United States
# No results found for Washington-Baltimore Corridor
# No results found for Winterville, NC United States
# No results found for Hawaii
# No results found for Northeast USA
# No results found for San Dimas, CA
# No results found for ...in Middle America
# No results found for NYC area
# No results found for CA
# No results found for Newcastle, UK
# No results found for Montreal, Canada
# No results found for USA
# No results found for Portland, OR
# No results found for Scotland, UK
# No results found for Alabama
# No results found for Michigan
# No results found for TRACY CA. USA
# No results found for Chicago, IL USA
# No results found for Seattle, WA USA
# No results found for Parts Unknown
# No results found for kansas city, mo USA
# No results found for nyc
# No results found for Winter Haven, FL USA
# No results found for NY, NY
# No results found for Brooklyn, NY USA
# No results found for Fresno, CA United States
# No results found for United States
# No results found for California San Mateo
# No results found for Hagerstown, MD United States
# No results found for Provincetown, MA United States
# No results found for TX
# No results found for USA
# No results found for Joliet, IL United States
# No results found for North but South
# No results found for Atlanta, GA USA
# No results found for Fairfield, CA United States
# No results found for Cape Coral, FL
# No results found for Cape Coral, FL
# No results found for Coeur d'Alene,ID
# No results found for Malang, Indonesia
# No results found for That  Lives in Northern Florida
# No results found for Arizona, USA
# No results found for Brooklyn
# No results found for vallejo, ca USA
# No results found for NYC
# No results found for SLC,UT
# No results found for Mid-Atlantic States
# No results found for England
# No results found for Toronto, Canada
# No results found for Michigan
# No results found for NC
# No results found for New England
# No results found for Baltimore, MD United States
# No results found for Chicago, IL United States
# No results found for Land of Lincoln
# No results found for Winterville, NC United States
# No results found for Gulfport, Florida USA
# No results found for Nairobi, Kenya
# No results found for Washington, DC
# No results found for Culver City, California
# No results found for Philadelphia,PA USA
# No results found for NY, NY USA
# No results found for Phoenix, AZ
# No results found for Nova Scotia, Canada
# No results found for vancouver, washington United States
# No results found for Chicago, Illinois USA
# No results found for Doha, Qatar
# No results found for WV
# No results found for PA
# No results found for Pacific Northwest
# No results found for Oakland, CA, USA
# No results found for seattle
# No results found for Rapid City, S.D. United States
# No results found for Moore Haven, FL USA
# No results found for Morrisville, PA USA
# No results found for Des Moines, WA
# No results found for Louisiana
# No results found for South Central PA, USA
# No results found for Virginia,  USA
# No results found for Paris, France
# No results found for Naperville, IL.
# No results found for Lancaster, Pennsylvania, USA
# No results found for San Mateo, CA United States
# No results found for Orange County, CA - USA
# No results found for Burnsville, NC  USA
# No results found for Clearwater, FL
# No results found for Texas
# No results found for Lathrup Village, MI United States
# No results found for Macomb Illinois
# No results found for CA, USA
# No results found for Pasadena, CA USA
# No results found for Panama City, FL United States
# No results found for San Luis Obispo, CA United States
# No results found for Everywhere
# No results found for San Antonio, Texas United States
# No results found for Brandon,mb
# No results found for Hawaii
# No results found for Astoria, N.Y. United States
# No results found for Provincetown, MA United States
# No results found for Sacramento, CA United States
# No results found for Seattle, WA USA
# No results found for San Antonio, TX USA
# No results found for USA
# No results found for Hollywood CA
# No results found for San Francisco, CA United States
# No results found for USA
# No results found for San Diego
# No results found for New York, NY
# No results found for ROCHESTER, NY
# No results found for Sydney, Australia
# No results found for USA
# No results found for San Francisco, CA United States
# No results found for Ames, IA United States
# Error fetching location info for Elizabethton, TN: Expecting value: line 1 column 1 (char 0)
# No results found for Evanston, Illinois United States
# No results found for Texas
# No results found for NZ
# No results found for Los Angeles, CA
# No results found for Columbus, OH
# No results found for Berkeley, CA United States
# No results found for San Jose, CA
# No results found for Melbourne, Australia
# No results found for Los Angeles, CA - USA
# No results found for MIAMI, FL United States
# No results found for Germantown, MD
# No results found for Cleveland, OH
# No results found for Georgia, USA
# No results found for Virginia, USA
# No results found for Thousand Oaks, CA USA
# No results found for Philadelphia, PA USA
# No results found for Fort Worth, Tx United States
# No results found for Tallahassee
# No results found for Lockport, NY  USA
# No results found for Seattle, home of 'Starbucks'....uh, yeah.
# No results found for GRAND PRAIRIE, Texas United States
# No results found for Malvern PA
# No results found for SILVER SPRING, MD United States
# No results found for Boston, Massachusetts United States
# No results found for Paris, Texas
# No results found for Kansas City, MO
# No results found for California
# No results found for Louisiana, USA
# No results found for CLEVELAND,OHIO
# No results found for DOWNTOWN IL. USA
# No results found for Calexico, CA
# No results found for Colorado Springs, CO United States
# No results found for McHenry, Illinois United States
# No results found for Lake Winola, PA USA
# No results found for Northwest Virginia
# No results found for Chicago, IL
# No results found for South Central PA, USA
# No results found for Ohio, USA
# No results found for Phoenix,AZ
# No results found for flushing ,ny
# No results found for Cape Coral, FL
# No results found for Seattle, WA USA
# No results found for Denton, TX USA
# No results found for port orchard, wa
# No results found for Kuwait
# No results found for Searcy, Arkansas
# No results found for Sacramento, CA
# No results found for San Clemente, Ca United States
# No results found for Mora, New Mexico, USA
# No results found for Hammond, IN United States
# No results found for North Syracuse, USA
# No results found for Virginia Beach, VA United States
# No results found for KUWAIT,Sabahiya
# No results found for Ithaca, NY United States
# No results found for Parts Unknown
# No results found for New York, NY USA
# No results found for yours
# No results found for New Milford, CT USA
# No results found for Valencia, Venezuela
# No results found for Ypsilanti, MI United States
# No results found for St. John, IN United States
# No results found for Williston, ND United States
# No results found for South Central PA, USA
# No results found for Scottsdale, Arizona United States
# No results found for Overland Park, KS  USA
# No results found for NY, NY
# No results found for Southwest, USA
# No results found for Texas (USA
# No results found for Hollyweird, CA
# No results found for Clinton, New Jersey United States
# No results found for Ohio United States
# No results found for Conn.
# No results found for Milwaukee, WI
# No results found for Alexandria, VA United States
# No results found for Miami, FL
# No results found for Ryder
# No results found for omaha, NE
# No results found for ARIZONA
# No results found for London, UK
# No results found for Philadelphia, PA
# No results found for Avon Lake, Oh United States
# No results found for Clarksburg, WV United States
# No results found for El Centro, CA
# No results found for Stevensville, MD United States
# No results found for Decatur, GA USA
# No results found for Seattle
# No results found for Valley Glen, CA USA
# No results found for Philadelphia, PA
# No results found for Avon Lake, Oh United States
# No results found for Clarksburg, WV United States
# No results found for Lee's Summit, MO United States
# No results found for Boulder, CO
# No results found for Toledo Ohio USA
# No results found for TX
# No results found for Charlotte, NC United States
# No results found for Campo, California United States
# No results found for Bowling Green, OH
# No results found for Canada
# No results found for Colome, SD  USA
# No results found for GLENDALE, CALIFORNIA
# No results found for Oakland, CA USA
# No results found for Seattle, WA
# No results found for Fresno, CA USA
# No results found for Tierra del Fuego, Argentina
# No results found for IL
# No results found for MI, United States
# No results found for USA
# No results found for Baltimore, Maryland USA
# No results found for Ypsilanti, MI United States
# No results found for abhi@abhinav.net - New Delhi, India
# No results found for Mexico City
# No results found for USA
# No results found for Arkham Asylum
# No results found for Lafayette, Louisiana
# No results found for Grand Forks, ND
# No results found for Texas, USA
# No results found for Pekin, IN USA
# No results found for In. USA
# No results found for Greece
# No results found for Usa
# No results found for Northwest, USA
# No results found for Harlingen, Texas United States
# No results found for California
# No results found for MD USA
# No results found for Dublin, OH United States
# No results found for Connecticut
# No results found for Chicago, IL
# No results found for Odessa, TX USA
# No results found for Brooklyn, New York
# No results found for Raleigh, NC USA
# No results found for Cleveland, OH
# No results found for Miami, FL
# No results found for TX
# No results found for West Texas Native
# No results found for Byram, MS USA
# No results found for Seattle, WA USA
# No results found for Ridgefield, CT United States
# No results found for usa
# No results found for Israel
# No results found for Ma. USA
# No results found for Hong Kong
# No results found for Land of the Fairies
# No results found for Sacramento CA
# No results found for The Haunted Noctuary
# No results found for Hippie Pacific NW
# No results found for Newport News, VA United States
# No results found for Wisconsin
# No results found for Buffalo, NY USA
# No results found for Oklahoma City, OK United States
# No results found for California
# No results found for Ohio, USA
# No results found for San Antonio, TX
# No results found for Dodge City, KS
# No results found for Palisades Park, NJ
# No results found for Los Angeles, CA USA
# No results found for Long Island, New York
# No results found for Port Orchard, WA United States
# No results found for Silicon Valley, CA United States
# No results found for Chicago, IL USA
# No results found for usa
# No results found for TN
# No results found for Pago Pago, American Samoa
# No results found for Tennessee
# No results found for Socorro, New Mexico USA.
# No results found for USA
# No results found for Sydney
# No results found for Andover
# No results found for South Central PA, USA
# No results found for Virginia Beach, VA USA
# No results found for Forli, Italy
# No results found for Osaka, Japan
# No results found for Houston
# No results found for honolulu
# No results found for Chicago, IL USA
# No results found for usa
# No results found for TN
# No results found for Pago Pago, American Samoa
# No results found for Tennessee
# No results found for Socorro, New Mexico USA.
# No results found for Atlanta, GA USA
# No results found for Phoenix,Arizona  USA
# No results found for Buenos Aires,  Argentina
# No results found for Pine, CO USA
# No results found for New Jersey
# No results found for Connecticut, USA
# No results found for Canada
# No results found for Savannah Ga.
# No results found for Savannah, Georgia
# No results found for Detroit, MI USA
# No results found for Woodbridge, SUFFOLK England
# No results found for a virtue/shortcoming depending on your point of view
# No results found for CT USA
# No results found for Wentzville, MO, USA
# No results found for Bangor, ME. USA
# No results found for Aurora, Colorado
# No results found for Cambridge
# No results found for New Jersey
# No results found for East Gretna, NE
# No results found for WAUKEGAN, ILLINOIS USA
# No results found for Austria
# No results found for USA
# No results found for Boston, MA United States
# No results found for Minneapolis, MN USA
# No results found for Chicago, IL United States
# No results found for Tucson, AZ
# No results found for Culver City, California
# No results found for Phila
# No results found for San Juan, P.R.
# No results found for "Once Upon A Time In America," "The Rocketeer," "A Beautiful Mind," Academy Award, 2001; hard to believe that she was just fourteen at the time
# No results found for CA USA
# No results found for OLLIERGUES France
# No results found for Martinsburg, WV USA
# No results found for Gillsville, GA USA
# No results found for Culver City, California
# No results found for United States
# No results found for That  Lives in Central Florida
# No results found for Astoria, Queens, New York City
# No results found for Williamsburg
# No results found for Columbus, OH
# No results found for Dearborn, Michigan United States
# No results found for United States
# No results found for West Texas Native
# No results found for Seminole, FL
# No results found for Baltimore Maryland
# No results found for Austin, TX
# No results found for Atlanta, GA USA
# No results found for Brooklyn, NY USA
# No results found for Orange County, CA - USA
# No results found for Roslindale, MA United States
# No results found for Florida
# No results found for Scottsdale, Arizona United States
# No results found for USA
# No results found for Atlanta, GA United States
# No results found for maryland
# No results found for New Orleans, Louisiana,USA
# No results found for Maryland
# No results found for Jersey City
# No results found for New Jersey
# No results found for Gardena, CA United States
# No results found for Texas
# No results found for Timisoara, Romania
# No results found for Tacoma, WA United States
# No results found for Sullivan, Illinois United States
# No results found for Springfield, Mo. USA
# No results found for Central California
# No results found for burnsville, mn United States

# %%
import pandas as pd
import os

# Define the folder where your CSV files are located
folder_path = '/content/drive/MyDrive/Sentiment_Sifters/data/processed/csv'

# Get all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# Check if there are any CSV files in the folder
if len(csv_files) == 0:
    print("No CSV files found in the folder.")
else:
    # Initialize an empty list to store DataFrames
    dataframes = []

    # Loop through each file and append to the list
    for file in csv_files:
        file_path = os.path.join(folder_path, file)
        try:
            df = pd.read_csv(file_path)
            dataframes.append(df)
        except Exception as e:
            print(f"Error reading {file}: {e}")

    # Only concatenate if we have dataframes
    if dataframes:
        # Concatenate all DataFrames into one
        combined_df = pd.concat(dataframes, ignore_index=True)

        # Check the number of rows in the combined DataFrame
        row_count = combined_df.shape[0]

        # Display the number of rows
        print(f'Total number of rows in the combined DataFrame: {row_count}')
    else:
        print("No DataFrames to concatenate.")

df.columns
# Out:
# Total number of rows in the combined DataFrame: 63480
# Index(['unique_id', 'asin', 'product_name', 'product_type', 'helpful',
#        'rating', 'title', 'date', 'reviewer', 'reviewer_location',
#        'review_text', 'country', 'region'],
#       dtype='object')
